# %%
# 1.Write a Python program to create a user-defined function, call the function, and display the returned value.

# %%
# Create user-defined function

# %%
def greet():
    print("Hello World")

# %%
# Call the function

# %%
result = greet()
# Out:
# Hello World

# %%
# Display returned value

# %%
greet()
# Out:
# Hello World

# %%
# 2.Write a Python program to find the factorial of a number using a function, display the result, and validate the input.

# %%
# Factorial of a number using a function and display result

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact = fact * i
    return fact
num = int(input("Enter a number: "))
result = factorial(num)
print("Factorial of", num, "is", result)
# Out:
# Enter a number:  10
# Factorial of 10 is 3628800

# %%
# Validate the input

# %%
try:
    num = int(input("Enter a number: "))
    if num < 0:
        print("Invalid input! Please enter a non-negative number.")
    else:
        print("Valid input:", num)
except ValueError:
    print("Invalid input! Please enter an integer only.")
# Out:
# Enter a number:  -10
# Invalid input! Please enter a non-negative number.

# %%
# 3.Write a Python program to check whether a number is prime using a function, count its factors, and display the result.

# %%
def is_prime(n):
    if n <= 1:
            return False
    for i in range(2, n):
        if n % i == 0:
            return False
            return True
num = int(input("Enter a number: "))
if is_prime(num):
    print(num, "is a Prime number")
else:
    print(num, "is not a Prime number")
# Out:
# Enter a number:  10
# 10 is not a Prime number

# %%
# Count its factors and display result

# %%
def count_factors(n):
    count = 0
    for i in range(1, n + 1):
        if n % i == 0:
            count += 1
    return count
def is_prime(n):
    return count_factors(n) == 2
num = int(input("Enter a number: "))
factors = count_factors(num)
if is_prime(num):
    print(num, "is a Prime number")
else:
    print(num, "is not a Prime number")
print("Number of factors:", factors)
# Out:
# Enter a number:  10
# 10 is not a Prime number
# Number of factors: 4

# %%
# 4.Write a Python program to find the largest of three numbers using a function, calculate their average, and display the smallest number.

# %%
# Find the largest of three numbers using a function

# %%
def largest(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))
result = largest(num1, num2, num3)
print("Largest number is:", result)
# Out:
# Enter first number:  88
# Enter second number:  45
# Enter third number:  34
# Largest number is: 88

# %%
# Calculate the average

# %%
average=(num1+num2+num3) / 3
print("Average=",average)
# Out:
# Average= 55.666666666666664

# %%
# Display smallest number

# %%
def smallest(num1,num2,num3):
    return min(num1,num2,num3)
print("Smallest number is:", smallest(num1,num2,num3))
# Out:
# Smallest number is: 34

# %%
# 5.Write a Python program to demonstrate default arguments, keyword arguments, and positional arguments.

# %%
# Default argument

# %%
def show(name="Guest"):
    print(name)

# %%
show()
# Out:
# Guest

# %%
# Positional argument

# %%
def show(name, age):
    print(name, age)

# %%
show("Shrawan", 25)
# Out:
# Shrawan 25

# %%
# Keyword argument

# %%
show(age=25, name="Shrawan")
# Out:
# Shrawan 25

# %%
# 6.Write a Python program to demonstrate the use of *args, calculate the sum, and find the maximum value.

# %%
# Use of *args and calculate sum

# %%
def add(*nums):
    print(sum(nums))

# %%
nums = [10, 20, 30, 40]
total = sum(nums)
print("Sum =", total)
# Out:
# Sum = 100

# %%
# Find maximum value

# %%
# 7.Write a Python program to demonstrate the use of **kwargs, display all key-value pairs, and count the arguments passed.

# %%
# Use of **kwargs and display all keys values pairs

# %%
def info(**data):
    print(data)

# %%
info(name="Shrawan", age=25)
# Out:
# {'name': 'Shrawan', 'age': 25}

# %%
# Count arguments passed

# %%
def info(**kwargs):
    print("Count =", len(kwargs))
info(name="Shrawan", age=25)
# Out:
# Count = 2

# %%
# 8.Write a Python program to calculate the factorial using recursion, count recursive calls, and display the result.

# %%
# Calculatebfactorial using recursion

# %%
def fact(n):
    if n == 1:
        return 1
    return n * fact(n - 1)
num = int(input("Enter a number: "))
print("Factorial =", fact(num))
# Out:
# Enter a number:  12
# Factorial = 479001600

# %%
# Count recursive calls and display result

# %%
count = 0
def fact(n):
    global count
    count += 1
    if n == 1:
        return 1
    return n * fact(n - 1)
num = int(input("Enter a number: "))
result = fact(num)
print("Recursive calls =", count)
# Out:
# Enter a number:  12
# Recursive calls = 12

# %%
# 9.Write a Python program to calculate the sum of digits using recursion, reverse the number, and count its digits.

# %%
# Calculate the sum of digits using recursion

# %%
def sum_digits(n):
    if n == 0:
        return 0
    return n % 10 + sum_digits(n // 10)
num = int(input("Enter a number:"))
print("Sum of digits =", sum_digits(num))
# Out:
# Enter a number: 12
# Sum of digits = 3

# %%
# Reverse the number

# %%
print("Reverse =", str(num)[::-1])
# Out:
# Reverse = 21

# %%
# Count its digits

# %%
len(str(num))
# Out:
# 2

# %%
# 10.Write a Python program using a lambda function to find the square, cube, and double of a number.

# %%
# Lambda function to find the square

# %%
square = lambda x: x * x
print(square(5))
# Out:
# 25

# %%
# Lambda function to find the cube

# %%
cube = lambda x: x * x * x
print(cube(5))
# Out:
# 125

# %%
# Double of a number

# %%
double = lambda x: x * 2
print(double(5))
# Out:
# 10

# %%
# 11.Write a Python program using map() to calculate squares, cubes, and square roots of list elements.

# %%
# Calculate squares using maps()

# %%
a = [1, 2, 3]
b = list(map(lambda x: x*x, a))
print(b)
# Out:
# [1, 4, 9]

# %%
# Calculate cubes using map()

# %%
a = [1, 2, 3]
b = list(map(lambda x: x*x*x, a))
print(b)
# Out:
# [1, 8, 27]

# %%
# Calculate square roots of list elements using map()

# %%
import math
a = [1, 4, 9]
b = list(map(math.sqrt, a))
print(b)
# Out:
# [1.0, 2.0, 3.0]

# %%
# 12.Write a Python program using filter() to extract even numbers, odd numbers, and numbers greater than a specified value.

# %%
# Even number using filter()

# %%
a = [1, 2, 3, 4, 5, 6]
even = list(filter(lambda x: x % 2 == 0, a))
print(even)
# Out:
# [2, 4, 6]

# %%
# Odd number using filter()

# %%
odd = list(filter(lambda x: x % 2 != 0, a))
print(list(odd))
# Out:
# [1, 3, 5]

# %%
# Number greater than specified value

# %%
greater = list(filter(lambda x: x > 3, a))
print(list(greater))
# Out:
# [4, 5, 6]

# %%
# 13.Write a Python program using reduce() to calculate the sum, product, and maximum value of list elements.

# %%
# Calculate sum using reduce()

# %%
from functools import reduce
a = [2, 3, 4,]
print(reduce(lambda x, y: x + y, a))
# Out:
# 9

# %%
# Calculate product using reduce()

# %%
a = [2, 3, 4]
product = reduce(lambda x, y: x * y, a)
print(product)
# Out:
# 24

# %%
# Maximum value of list elements

# %%
max(a)
# Out:
# 4

# %%
# 14.Write a Python program to create a text file, write data into it, and close the file properly.

# %%
# Create a text file

# %%
f = open("sample.txt", "w")
f.close()
print("File created")
# Out:
# File created

# %%
# Write data into it

# %%
with open("sample.txt", "w") as f:
    f.write("Name: Shrawan\n")
    f.write("Role: Data Scientist\n")
    f.write("Location: India\n")

# %%
# Close the file properly

# %%
f.close()

# %%
# 15.Write a Python program to read a text file, count the number of lines, and display the contents.

# %%
# Read a text file

# %%
with open("sample.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# Name: Shrawan
# Role: Data Scientist
# Location: India

# %%
# Count number of lines

# %%
with open("sample.txt", "r") as f:
    lines = f.readlines()
print("Number of lines =", len(lines))
# Out:
# Number of lines = 3

# %%
# Display contents

# %%
with open("sample.txt", "r") as f:
    print(f.read())
# Out:
# Name: Shrawan
# Role: Data Scientist
# Location: India

# %%
# 16.Write a Python program to append data to a file, display the updated contents, and count the total words.

# %%
# Append data to a file

# %%
with open("sample.txt", "a") as f:
    f.write("Appended line 1\n")
    f.write("Appended line 2\n")

# %%
# Display updated contents

# %%
with open("sample.txt", "r") as f:
    print(f.read())
# Out:
# Name: Shrawan
# Role: Data Scientist
# Location: India
# Appended line 1
# Appended line 2

# %%
# Count total words

# %%
with open("sample.txt", "r") as f:
    data = f.read()
print("Total words =", len(data.split()))
# Out:
# Total words = 13

# %%
# 17.Write a Python program to copy the contents of one file to another, compare both files, and display the file sizes.

# %%
# Copy content of one file to another

# %%
f1 = open("sample.txt", "r")
f2 = open("python.txt", "w")
f2.write(f1.read())
print("Copied")
# Out:
# Copied

# %%
# Compare both files

# %%
f1 = open("sample.txt", "r")
f2 = open("python.txt", "r")
print(f1.read() == f2.read())
# Out:
# True

# %%
# Display the files sizes

# %%
import os
print("sample size =", os.path.getsize("sample.txt"))
print("python size =", os.path.getsize("python.txt"))
# Out:
# sample size = 88
# python size = 88

# %%
# 18.Write a Python program to search for a word in a file, count its occurrences, and replace it with another word.

# %%
# Search for a word in a file

# %%
with open("sample.txt", "r") as f:
    print("Shrawan" in f.read())
# Out:
# True

# %%
# Count its occurrences

# %%
with open("sample.txt", "r") as f:
    print(f.read().count("Appended"))
# Out:
# 2

# %%
# Replace it with another word

# %%
with open("sample.txt", "r") as f:
    data = f.read()
with open("python.txt", "w") as f:
    f.write(data.replace("Shrawan", "Omkar"))
print("Done")
# Out:
# Done

# %%
# 19.Write a Python program to create multiple files, list all created files, and delete a selected file.

# %%
# Create multiple files

# %%
open("java.txt", "w").close()
open("DSU.txt", "w").close()
open("SQL.txt", "w").close()
print("Created")
# Out:
# Created

# %%
# List all created files

# %%
import os
files = os.listdir()
for f in files:
    if f.endswith(".txt"):
        print(f)
# Out:
# DSU.txt
# java.txt
# python.txt
# sample.txt
# SQL.txt

# %%
# Delete a selected file

# %%
import os
os.remove("DSU.txt")

# %%
import os
os.remove("SQL.txt")

# %%
import os
os.remove("java.txt")

# %%
# 20.Write a Python program to handle division-by-zero exceptions, display a custom error message, and continue execution.

# %%
# Division-by-zero exception

# %%
try:
    print(10 / 0)
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# Display custom error message

# %%
try:
    print(10 / 0)
except ZeroDivisionError:
    print("Error: Cannot divide by zero")
# Out:
# Error: Cannot divide by zero

# %%
# Continue Execution

# %%
try:
    print(10 / 0)
except:
    print("Error: division by zero")
print("Program continues")
# Out:
# Error: division by zero
# Program continues

# %%
# 21.Write a Python program to handle multiple exceptions, display the exception type, and log the error message.

# %%
# Multiple exceptions

# %%
try:
    num = int("abc")
    result = 10 / num
except ValueError:
    print("Conversion failed")
except ZeroDivisionError:
    print("Division by zero error")
# Out:
# Conversion failed

# %%
# Display the exception type

# %%
try:
    result = 10 / 0
except Exception as e:
    print(type(e))
    print(e)
# Out:
# <class 'ZeroDivisionError'>
# division by zero

# %%
# Log the error message

# %%
try:
    print(10/0)
except Exception as e:
    open("python.txt", "a").write(str(e) + "\n")
    print("Logged")
# Out:
# Logged

# %%
# 22.Write a Python program to demonstrate try, except, and finally, and display execution flow messages.

# %%
# try,except,finally and display execution flow message

# %%
try:
    print("Try block")
    print(10/0)
except:
    print("Except block")
finally:
    print("Finally block")
# Out:
# Try block
# Except block
# Finally block

# %%
# 23.Write a Python program to raise a custom exception, handle the exception, and display a user-friendly message.

# %%
# Raise a custom exception

# %%
class MyError(Exception):
    pass
age = int(input("Enter age: "))
if age < 18:
    raise MyError("Age is too low!")
else:
    print("Allowed")
# Out:
# Enter age:  20
# Allowed

# %%
# Handle exception

# %%
class MyError(Exception):
    pass
try:
    age = int(input("Enter age: "))
    if age < 18:
        raise MyError("Not allowed")
    print("Allowed")
except MyError as e:
    print("Error:", e)
# Out:
# Enter age:  15
# Error: Not allowed

# %%
# Display user-friendly message

# %%
class MyError(Exception):
    pass
try:
    age = int(input("Enter age: "))
    if age < 18:
        raise MyError
    print("You are allowed")
except MyError:
    print("Sorry! You are not eligible (must be 18 or above).")
# Out:
# Enter age:  19
# You are allowed

# %%
# 24.Write a Python program to handle a file-not-found exception, create the missing file, and write default content into it.

# %%
# File not found exception

# %%
try:
    f = open("java.txt", "r")
    print(f.read())
except FileNotFoundError:
    print("File not found!")
# Out:
# File not found!

# %%
# Create the missing file

# %%
try:
    f = open("java.txt", "r")
    print(f.read())
except FileNotFoundError:
    print("File not found.")
    f = open("java.txt", "w")
    f.write("Default content")
    print("File created")
# Out:
# File not found.
# File created

# %%
# Write default content into it

# %%
try:
    f = open("java.txt", "r")
    print(f.read())
except FileNotFoundError:
    print("File not found. Creating file...")
    f = open("java.txt", "w")
    f.write("Hello! This is default content.")
    print("Default content written into file.")
# Out:
# Default content

# %%
# 25.Write a Python program to create a custom exception class, validate user input, and handle invalid data.

# %%
# Create a custom exception class

# %%
class MyError(Exception):
    pass
print("Custom exception created")
# Out:
# Custom exception created

# %%
# Validate user input

# %%
class InvalidInput(Exception): 
    pass
try:
    n = int(input("Enter 1 to 10: "))
    if n < 1 or n > 10: raise InvalidInput
    print("Valid input")
except: print("Invalid input!")
# Out:
# Enter 1 to 10:  9
# Valid input

# %%
# Handle invalid data

# %%
try:
    n = int(input("Enter number: "))
    print("Valid:", n)
except:
    print("Invalid data!")
# Out:
# Enter number:  11
# Valid: 11
