# %%
# 1.Write a Python program to accept a number, check whether it is positive, negative, or zero, and display an appropriate message.

# %%
# Check whether number is positive,negative,or zero and display appropriate message

# %%
n = int(input("Enter a number: "))
if n > 0:
    print(" Number is Positive number")
elif n < 0:
    print("Number is Negative number")
else:
    print("Number is Zero")
# Out:
# Enter a number:  10
#  Number is Positive number

# %%
# 2.Write a Python program to accept a number, check whether it is even or odd, and display its square.

# %%
# Check whether number is even or odd

# %%
n = int(input("Enter a number: "))
if n % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number:  2
# Even number

# %%
# Display its square

# %%
print("Square:", n*n)
# Out:
# Square: 4

# %%
# 3.Write a Python program to accept two numbers, find the larger number, and check whether both numbers are equal.

# %%
# Accept two numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
# Out:
# Enter first number:  10
# Enter second number:  20

# %%
# Find larger number

# %%
max(a,b)
# Out:
# 20

# %%
# Check whether both numbers are equal

# %%
a == b
# Out:
# False

# %%
# 4.Write a Python program to accept three numbers, find the largest number, smallest number, and their average.

# %%
# Accept three numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
# Out:
# Enter first number:  10
# Enter second number:  25
# Enter third number:  40

# %%
# Find largest number

# %%
max(a,b,c)
# Out:
# 40

# %%
# Find smallest number

# %%
min(a,b,c)
# Out:
# 10

# %%
# Average

# %%
avg = (a + b + c) / 3
print("Average:", avg)
# Out:
# Average: 25.0

# %%
# 5.Write a Python program to accept marks of five subjects, calculate total marks, percentage, and grade using if-elif-else.

# %%
# Accept marks of five subjects

# %%
java = int(input("Enter java marks: "))
oop = int(input("Enter oop marks: "))
python = int(input("Enter python marks: "))
sql = int(input("Enter sql marks: "))
dsu = int(input("Enter dsu marks: "))
# Out:
# Enter java marks:  89
# Enter oop marks:  88
# Enter python marks:  70
# Enter sql marks:  90
# Enter dsu marks:  78

# %%
# Calculate total marks

# %%
total = java+oop+python+sql+dsu

# %%
print(total)
# Out:
# 415

# %%
# Percentage

# %%
415 / 5
# Out:
# 83.0

# %%
# Grade using if-elif-else

# %%
if total > 460:
    print("Grade A")
elif total > 400:
    print("Grade B")
elif total > 350:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
# 6.Write a Python program to check whether a student has passed or failed based on marks in each subject, total marks, and percentage.

# %%
# Check whether student has passed or failed based on marks in each subject

# %%
m1 = int(input("Enter marks 1: "))
m2 = int(input("Enter marks 2: "))
m3 = int(input("Enter marks 3: "))
m4 = int(input("Enter marks 4: "))
m5 = int(input("Enter marks 5: "))
if m1 >= 40 and m2 >= 40 and m3 >= 40 and m4 >= 40 and m5 >= 40:
    print("Student Passed")
else:
    print("Student Failed")
# Out:
# Enter marks 1:  67
# Enter marks 2:  89
# Enter marks 3:  87
# Enter marks 4:  67
# Enter marks 5:  89
# Student Passed

# %%
# Total Marks

# %%
total = m1+m2+m3+m4+m5

# %%
print(total)
# Out:
# 399

# %%
# Percentage

# %%
399 / 5
# Out:
# 79.8

# %%
# 7.Write a Python program to check whether a year is a leap year, century year, or ordinary year.

# %%
# Check whether year is leap year,century year, or ordinary year

# %%
y = int(input("Enter year: "))
if y % 100 == 0:
    print("Century year")
elif y % 4 == 0:
    print("Leap year")
else:
    print("Ordinary year")
# Out:
# Enter year:  2000
# Century year

# %%
# 8.Write a Python program to check whether a character is a vowel, consonant, digit, or special symbol.

# %%
# Check whether character is a vowel,consonant,digit,or symbol

# %%
ch = input("Enter a character: ")
if ch.isdigit():
    print("Digit")
elif ch in "aeiouAEIOU":
    print("Vowel")
elif ch.isalpha():
    print("Consonant")
else:
    print("Symbol")
# Out:
# Enter a character:  P
# Consonant

# %%
# 9.Write a Python program to check whether a character is uppercase, lowercase, digit, or special character.

# %%
# Check whether character is uppercase,lowercase,digit,or special character

# %%
ch = input("Enter a character: ")
if ch.isupper():
    print("Uppercase letter")
elif ch.islower():
    print("Lowercase letter")
elif ch.isdigit():
    print("Digit")
else:
    print("Special character")
# Out:
# Enter a character:  SHRAWAN
# Uppercase letter

# %%
# 10.Write a Python program to check whether a number is divisible by 5, 11, both 5 and 11, or neither.

# %%
# Check whether a number is divisible by 5, 11, both 5 and 11, or neither

# %%
n = int(input("Enter a number: "))
if n % 5 == 0 and n % 11 == 0:
    print("Divisible by both 5 and 11")
elif n % 5 == 0:
    print("Divisible by 5")
elif n % 11 == 0:
    print("Divisible by 11")
else:
    print("Not divisible by 5 or 11")
# Out:
# Enter a number:  50
# Divisible by 5

# %%
# 11.Write a Python program to check whether a number is divisible by 2, 3, and 6 using logical operators.

# %%
# Check whether a number is divisible by 2, 3, and 6 using logical operators.

# %%
n = int(input("Enter a number: "))
if n % 2 == 0 and n % 3 == 0 and n % 6 == 0:
    print("Divisible by 2, 3 and 6")
else:
    print("Not divisible by 2, 3 and 6")
# Out:
# Enter a number:  7
# Not divisible by 2, 3 and 6

# %%
# 12.Write a Python program to accept the age of a person, check voting eligibility, senior citizen status, and driving eligibility.

# %%
# Accept the age of a person, check voting eligibility, senior citizen status, and driving eligibility.

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Eligible for voting")
    print("Eligible for driving")
else:
    print("Not eligible for voting or driving")
if age >= 60:
    print("Senior citizen")
else:
    print("Not a senior citizen")
# Out:
# Enter your age:  60
# Eligible for voting
# Eligible for driving
# Senior citizen

# %%
# 13.Write a Python program to calculate electricity bill charges based on unit slab rates and display the final bill amount.

# %%
# Calculate electricity bill chargers based on unit slab rates and display final bill amount

# %%
units = int(input("Enter electricity units consumed: "))
bill = 0
if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = (100 * 1.5) + (units - 100) * 2.5
elif units <= 300:
    bill = (100 * 1.5) + (100 * 2.5) + (units - 200) * 4
else:
    bill = (100 * 1.5) + (100 * 2.5) + (100 * 4) + (units - 300) * 6
print("Total Electricity Bill = ₹", bill)
# Out:
# Enter electricity units consumed:  78
# Total Electricity Bill = ₹ 117.0

# %%
# 14.Write a Python program to calculate income tax based on income slabs and display the tax amount.

# %%
# Calculate income tax based on income slabs and display the tax amount.

# %%
income = float(input("Enter income: "))
tax = 0
if income > 1000000:
    tax = (income - 1000000) * 0.30 + 125000
elif income > 500000:
    tax = (income - 500000) * 0.20 + 25000
elif income > 250000:
    tax = (income - 250000) * 0.05
print("Tax =", tax)
# Out:
# Enter income:  1000000
# Tax = 125000.0

# %%
# 15.Write a Python program to create a menu-driven calculator using if-elif-else for addition, subtraction, multiplication, and division.

# %%
# Create a menu-driven calculator using if-elif-else for addition, subtraction, multiplication, and division.

# %%
choice = int(input("Enter your choice (1-4): "))
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
if choice == 1:
    print("Result =", a + b)
elif choice == 2:
    print("Result =", a - b)
elif choice == 3:
    print("Result =", a * b)
elif choice == 4:
    if b != 0:
        print("Result =", a / b)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid choice")
# Out:
# Enter your choice (1-4):  1
# Enter first number:  10
# Enter second number:  20
# Result = 30.0

# %%
# 16.Write a Python program to create a menu-driven program to find area of circle, rectangle, triangle, and square.

# %%
# Create a menu-driven program to find area of circle, rectangle, triangle, and square.

# %%
choice = int(input("Enter your choice (1-4): "))
if choice == 1:
    r = float(input("Enter radius: "))
    print("Area of Circle =", 3.14 * r * r)
elif choice == 2:
    l = float(input("Enter length: "))
    b = float(input("Enter breadth: "))
    print("Area of Rectangle =", l * b)
elif choice == 3:
    b = float(input("Enter base: "))
    h = float(input("Enter height: "))
    print("Area of Triangle =", 0.5 * b * h)
elif choice == 4:
    s = float(input("Enter side: "))
    print("Area of Square =", s * s)
else:
    print("Invalid choice")
# Out:
# Enter your choice (1-4):  3
# Enter base:  4
# Enter height:  6
# Area of Triangle = 12.0

# %%
# 17.Write a Python program to check whether three sides form a valid triangle, identify its type, and calculate its perimeter.

# %%
# Check whether three sides form a valid triangle.

# %%
a = int(input("a: "))
b = int(input("b: "))
c = int(input("c: "))
if a+b>c and a+c>b and b+c>a:
    print("Valid Triangle")
else:
    print("Not Valid Triangle")
# Out:
# a:  2
# b:  2
# c:  2
# Valid Triangle

# %%
# Identify its type

# %%
if a+b>c and a+c>b and b+c>a:
    print("Equilateral" if a==b==c else "Isosceles" if a==b or b==c or a==c else "Scalene")
else:
    print("Not a Triangle")
# Out:
# Equilateral

# %%
# 18.Write a Python program to check whether three angles form a valid triangle and identify whether it is acute, right, or obtuse.

# %%
# Check whether three angles form a valid triangle

# %%
a = int(input("Angle 1: "))
b = int(input("Angle 2: "))
c = int(input("Angle 3: "))
if a + b + c == 180:
    print("Valid Triangle")
else:
    print("Not a Valid Triangle")
# Out:
# Angle 1:  60
# Angle 2:  60
# Angle 3:  60
# Valid Triangle

# %%
# Identify whether it is acute, right, or obtuse

# %%
if a + b + c == 180:
    if a == 90 or b == 90 or c == 90:
        print("Right Triangle")
    elif a > 90 or b > 90 or c > 90:
        print("Obtuse Triangle")
    else:
        print("Acute Triangle")
else:
    print("Not a Valid Triangle")
# Out:
# Acute Triangle

# %%
# 19.Write a Python program to accept month number, display the month name, and show the number of days in that month.

# %%
# Accept month number

# %%
m = int(input("Enter month number: "))
print("Month number entered is:", m)
# Out:
# Enter month number:  3
# Month number entered is: 3

# %%
# Display month name and show number of days in that month

# %%
if m == 1:
    print("Jan - 31 days")
elif m == 2:
    print("Feb - 28/29 days")
elif m == 3:
    print("Mar - 31 days")
elif m == 4:
    print("Apr - 30 days")
elif m == 5:
    print("May - 31 days")
elif m == 6:
    print("Jun - 30 days")
elif m == 7:
    print("Jul - 31 days")
elif m == 8:
    print("Aug - 31 days")
elif m == 9:
    print("Sep - 30 days")
elif m == 10:
    print("Oct - 31 days")
elif m == 11:
    print("Nov - 30 days")
elif m == 12:
    print("Dec - 31 days")
else:
    print("Invalid month")
# Out:
# Mar - 31 days

# %%
# 20.Write a Python program to accept a weekday number, display the weekday name, and identify whether it is a weekday or weekend.

# %%
# Accept a weekday number

# %%
n = int(input("Enter weekday number (1-7): "))
print("Weekday number entered is:", n)
# Out:
# Enter weekday number (1-7):  5
# Weekday number entered is: 5

# %%
# Display the weekday name, and identify whether it is a weekday or weekend.

# %%
if n == 1:
    print("Monday - Weekday")
elif n == 2:
    print("Tuesday - Weekday")
elif n == 3:
    print("Wednesday - Weekday")
elif n == 4:
    print("Thursday - Weekday")
elif n == 5:
    print("Friday - Weekday")
elif n == 6:
    print("Saturday - Weekend")
elif n == 7:
    print("Sunday - Weekend")
else:
    print("Invalid input")
# Out:
# Friday - Weekday

# %%
# 21.Write a Python program to accept temperature, classify it as cold, normal, hot, or very hot, and convert it between Celsius and Fahrenheit.

# %%
# Accept temperature

# %%
t = float(input("Enter temperature: "))
print("Temperature entered is:", t)
# Out:
# Enter temperature:  40
# Temperature entered is: 40.0

# %%
# Classify it as cold, normal, hot, or very hot

# %%
if t < 15:
    print("Cold")
elif t < 25:
    print("Normal")
elif t < 35:
    print("Hot")
else:
    print("Very Hot")
# Out:
# Very Hot

# %%
# Convert it between Celsius and Fahrenheit.

# %%
if ch == 1:
    print("Fahrenheit =", (t * 9/5) + 32)
elif ch == 2:
    print("Celsius =", (t - 32) * 5/9)
else:
    print("Invalid choice")
# Out:
# Celsius = 4.444444444444445

# %%
# 22.Write a Python program to accept a password, check its length, validate whether it contains letters and digits, and display password strength.

# %%
# Accept a password

# %%
pwd = input("Enter password: ")
print("Password accepted")
# Out:
# Enter password:  Shrawan123
# Password accepted

# %%
# Check its length

# %%
len(pwd)
# Out:
# 10

# %%
# Validate whether it contains letters and digits

# %%
if any(c.isalpha() for c in pwd) and any(c.isdigit() for c in pwd):
    print("Valid Password")
else:
    print("Invalid Password")
# Out:
# Valid Password

# %%
# Display password strength

# %%
if len(pwd) < 5:
    print("Weak")
elif len(pwd) < 8:
    print("Medium")
else:
    print("Strong")
# Out:
# Strong

# %%
# 23.Write a Python program to accept a product price, apply discount based on price range, and calculate the final price.

# %%
# Accept a product price

# %%
price = float(input("Enter product price: "))
print("Product price is:", price)
# Out:
# Enter product price:  15000
# Product price is: 15000.0

# %%
# Apply discount based on price range and calculate final price

# %%
if price <= 1000:
    discount = 0
elif price <= 5000:
    discount = price * 0.05
elif price <= 10000:
    discount = price * 0.10
else:
    discount = price * 0.15
final_price = price - discount

print("Discount =", discount)
print("Final Price =", final_price)
# Out:
# Discount = 2250.0
# Final Price = 12750.0

# %%
# 24.Write a Python program to accept employee salary, calculate bonus based on salary range, and display total salary.

# %%
# Accept employee salary

# %%
sal = float(input("Enter employee salary: "))
print("Salary is:", sal)
# Out:
# Enter employee salary:  50000
# Salary is: 50000.0

# %%
# Calculate bonus based on salary range and display total salary

# %%
if sal <= 10000:
    bonus = sal * 0.10
elif sal <= 50000:
    bonus = sal * 0.07
else:
    bonus = sal * 0.05
print("Bonus =", bonus)
print("Total Salary =", sal + bonus)
# Out:
# Bonus = 3500.0000000000005
# Total Salary = 53500.0

# %%
# 25.Write a Python program to accept a number and use a conditional expression to find whether it is even or odd, positive or negative, and greater than 100.

# %%
# Accept a number and use a conditional expression to find whether it is even or odd

# %%
n = int(input("Enter a number: "))
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  10
# Even

# %%
# Positive or negative

# %%
if n > 0:
    print("Positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positive

# %%
# Greater than 100

# %%
if n > 100:
    print("Greater than 100")
else:
    print("Not greater than 100")
# Out:
# Not greater than 100
