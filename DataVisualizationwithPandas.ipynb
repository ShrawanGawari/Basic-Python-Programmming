# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame({
    "A":[50,60,70,80],
    "B":[40,55,65,75],
    "C":[30,45,55,65],
    "D":[20,35,45,55]
},index =["Q1","Q2","Q3","Q4"])

# %%
df
# Out:
#      A   B   C   D
# Q1  50  40  30  20
# Q2  60  55  45  35
# Q3  70  65  55  45
# Q4  80  75  65  55

# %%
df.shape
# Out:
# (4, 4)

# %%
df.isnull()
# Out:
#         A      B      C      D
# Q1  False  False  False  False
# Q2  False  False  False  False
# Q3  False  False  False  False
# Q4  False  False  False  False

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.scatter(x="A",y="B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df["A"].plot.pie()
# Out:
# <Axes: ylabel='A'>

# %%
df = pd.DataFrame({
    "ProductA": [120, 135, 128, 140],
    "ProductB": [85, 90, 88, 95],
    "ProductC": [60, 70, 75, 80],
    "ProductD": [95, 100, 105, 110]
},index=["Week1","Week2","Week3","Week4"])

# %%
df
# Out:
#        ProductA  ProductB  ProductC  ProductD
# Week1       120        85        60        95
# Week2       135        90        70       100
# Week3       128        88        75       105
# Week4       140        95        80       110

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df["ProductA"].plot.pie()
# Out:
# <Axes: ylabel='ProductA'>
