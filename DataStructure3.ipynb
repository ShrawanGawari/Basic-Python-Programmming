# %%
nums = (1,2,3,4,5)
print(nums)
# Out:
# (1, 2, 3, 4, 5)

# %%
set(nums)
# Out:
# {1, 2, 3, 4, 5}

# %%
# set intersection

# %%
a = {1,2,3}
b = {2,3,4}

# %%
# common elements

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
# using &

# %%
a & b
# Out:
# {2, 3}

# %%
# copying set

# %%
a = {1,2,3}

# %%
# copying sets

# %%
b = a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
# nested sets using frozensets()

# %%
# normal sets cannot contains sets
# use frozenset for nested sets

# %%
a = frozenset({1,2})

# %%
b = {a,3}

# %%
b
# Out:
# {3, frozenset({1, 2})}

# %%
# frozen set

# %%
frozen = frozenset([1,2,3])

# %%
type(frozen)
# Out:
# frozenset

# %%
# create dictionary

# %%
Student = {
    "name":"Shrawan",
    "age":19
}

# %%
print(Student)
# Out:
# {'name': 'Shrawan', 'age': 19}

# %%
Cars = {
    "name":"Sierra",
    "model":"2008"
}
print(Cars)
# Out:
# {'name': 'Sierra', 'model': '2008'}

# %%
flowers = {
    "rose":"red",
    "lotus":"pink",
    "sunflower":"yellow"
}
print(flowers)
# Out:
# {'rose': 'red', 'lotus': 'pink', 'sunflower': 'yellow'}

# %%
states = {
    "Maharashtra":"Mumbai",
    "Gujarat":"Gandhinagar",
    "Karnataka":"Bengaluru"
}
print(states)
# Out:
# {'Maharashtra': 'Mumbai', 'Gujarat': 'Gandhinagar', 'Karnataka': 'Bengaluru'}

# %%
# mixed datatype dictionary

# %%
mixed = {
    1:"one",
    "name":"Python",
    True:100
}
print(mixed)
# Out:
# {1: 100, 'name': 'Python'}

# %%
mixed = {
    3:"Three",
    "name":"Java",
    True:200
}
print(mixed)
# Out:
# {3: 'Three', 'name': 'Java', True: 200}

# %%
mixed["name"]
# Out:
# 'Java'

# %%
mixed.get(3)
# Out:
# 'Three'

# %%
# adding elements

# %%
Student = {
    "name":"Shrawan"
}

# %%
# add new key-value pair

# %%
Student["age"] = 20

# %%
Student
# Out:
# {'name': 'Shrawan', 'age': 20}

# %%
# add another value

# %%
Student["Marks"] = 99

# %%
Student
# Out:
# {'name': 'Shrawan', 'age': 20, 'Marks': 99}

# %%
# modify value

# %%
Student["age"] = 25

# %%
Student
# Out:
# {'name': 'Shrawan', 'age': 25, 'Marks': 99}

# %%
Student.popitem()
# Out:
# ('Marks', 99)

# %%
Student
# Out:
# {'name': 'Shrawan'}

# %%
# delete using del

# %%
del Student["name"]

# %%
Student
# Out:
# {}

# %%
# remove all elements

# %%
Student.clear()

# %%
Student
# Out:
# {}

# %%
Student = {
    "name":"Shrawan",
    "age":19
}

# %%
# finding length

# %%
len(Student)
# Out:
# 2

# %%
# checking keys

# %%
"age" in Student
# Out:
# True

# %%
"salary" in Student
# Out:
# False

# %%
# loop through keys

# %%
Student = {
    "name":"Shrawan",
    "age":19
}

# %%
for Student in Student:
    Student
    print(Student)
# Out:
# name
# age

# %%
# loop through values

# %%
for value in Student.values():
    value
    print(value)
# Out:
# Shrawan
# 19

# %%
for item in Student.items():
    item
    print(item)
# Out:
# ('name', 'Shrawan')
# ('age', 19)

# %%
# Dictionary keys

# %%
Student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
Student.values()
# Out:
# dict_values(['Shrawan', 19])

# %%
Student.items()
# Out:
# dict_items([('name', 'Shrawan'), ('age', 19)])

# %%
# copy dictionary

# %%
new_Student = Student.copy()

# %%
new_Student
# Out:
# {'name': 'Shrawan', 'age': 19}

# %%
# nested dictionaries

# %%
Students = {
    "student1":{
    "name":"Shrawan",
    "age":19
},
    "student2":{
    "name":"Omkar",
    "age":20
}
}

# %%
# access nested value

# %%
Students["student1"]["name"]
# Out:
# 'Shrawan'

# %%
# create dictionary

# %%
Student = {
    "name":"shrawan",
    "age":19,
    "course":"java"
}

# %%
# access and display dictionary values

# %%
print(Student)
# Out:
# {'name': 'shrawan', 'age': 19, 'course': 'java'}

# %%
# add a new key value pair

# %%
Student["salary"]=10000

# %%
Student
# Out:
# {'name': 'shrawan', 'age': 19, 'course': 'java', 'salary': 10000}

# %%
# update an existing value

# %%
Student["age"]=25

# %%
Student
# Out:
# {'name': 'shrawan', 'age': 25, 'course': 'java', 'salary': 10000}

# %%
# delete a key value pair

# %%
del Student["age"]

# %%
Student
# Out:
# {'name': 'shrawan', 'course': 'java', 'salary': 10000}

# %%
# display all keys and values of dictionary

# %%
Student.items()
# Out:
# dict_items([('name', 'shrawan'), ('course', 'java'), ('salary', 10000)])
