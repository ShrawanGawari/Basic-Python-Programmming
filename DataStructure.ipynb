# %%
# Data structures

# %%
# Data structures are used to store and organize data so it can be used efficiently.

# %%
# List

# %%
# A list is an ordered, mutable (changeable) collection of items

# %%
nums = [10,20,30,40]
type(nums)
# Out:
# list

# %%
nums = [10,20,30,40]
print(nums)
# Out:
# [10, 20, 30, 40]

# %%
# Tuple

# %%
# A tuple is an ordered, immutable (not changeable) collection

# %%
t = (10,20,30)
type(t)
# Out:
# tuple

# %%
t = (10,20,30)
print(t)
# Out:
# (10, 20, 30)

# %%
# Set

# %%
# A set is an unordered collection of unique elements

# %%
s = {1,2,3,3,4}
type(s)
# Out:
# set

# %%
s = {1,2,3,3,4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
# Dictionary

# %%
# A dictionary stores data in key-value pairs

# %%
student = {
    "name":"Shrawan",
    "age":19
}
type(student)
# Out:
# dict

# %%
student = {
    "name":"Shrawan",
    "age":19
} 
print(student)
# Out:
# {'name': 'Shrawan', 'age': 19}

# %%
Cars = {
    "name":"Sierra",
    "model":"2026"
}
print(Cars)
# Out:
# {'name': 'Sierra', 'model': '2026'}

# %%
Student = {
    "name":"Shrawan",
    "age":19,
    "Subject":"Java",
    "Car":"BMW"
}
print(Student)
# Out:
# {'name': 'Shrawan', 'age': 19, 'Subject': 'Java', 'Car': 'BMW'}

# %%
# Creating List

# %%
numbers = [1,2,3,4,5]
type(numbers)
# Out:
# list

# %%
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Empty list

# %%
empty_list = []
print(empty_list)
# Out:
# []

# %%
# Integer list

# %%
numbers = [1, 2, 3, 4]

# %%
type(numbers)
# Out:
# list

# %%
# String list

# %%
Fruits = ["manga","banana","apple"]
print(Fruits)
# Out:
# ['manga', 'banana', 'apple']

# %%
type(Fruits)
# Out:
# list

# %%
# Mixed list

# %%
mixed = [1,"Python",8.8, True]
print(mixed)
# Out:
# [1, 'Python', 8.8, True]

# %%
type(mixed)
# Out:
# list

# %%
# Accessing elements

# %%
fruits = ["apple","banana","mango"]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-1]
# Out:
# 'mango'

# %%
fruits[-1]
# Out:
# 'mango'

# %%
# List Slicing

# %%
nums = [10,20,30,40,50]

# %%
# elements from index 1 to 3

# %%
nums[1:4]
# Out:
# [20, 30, 40]

# %%
# from beginning to index 2

# %%
nums[:3]
# Out:
# [10, 20, 30]

# %%
# from index 2 to end

# %%
nums[2:]
# Out:
# [30, 40, 50]

# %%
# Modifying List Elements

# %%
colors = ["red", "blue", "green"]

# %%
# Changing element

# %%
colors[1] = "yellow"

# %%
colors
# Out:
# ['red', 'yellow', 'green']

# %%
colors[2] = "Pink"

# %%
colors
# Out:
# ['red', 'yellow', 'Pink']

# %%
Cars = ["BMW","Audi","Fortuner"]

# %%
Cars[0] = "Auto"

# %%
Cars
# Out:
# ['Auto', 'Audi', 'Fortuner']

# %%
# Adding Elements

# %%
nums = [1, 2, 3]

# %%
# Adding single element at end

# %%
nums.append(4)

# %%
nums
# Out:
# [1, 2, 3, 4]

# %%
nums.append(5)

# %%
nums
# Out:
# [1, 2, 3, 4, 5]

# %%
nums.append(6)

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Adding element at specific position

# %%
nums.insert(1,100)

# %%
nums
# Out:
# [1, 100, 2, 3, 4, 5, 6]

# %%
# Adding multiple elements

# %%
nums.extend([7,8])

# %%
nums
# Out:
# [1, 100, 2, 3, 4, 5, 6, 7, 8]

# %%
# Remove specific element

# %%
fruits = ["apple", "banana", "mango"]

# %%
fruits.remove("banana")

# %%
fruits
# Out:
# ['apple', 'mango']

# %%
# Remove last element

# %%
nums = [10, 20, 30]

# %%
nums.pop()
# Out:
# 30

# %%
nums
# Out:
# [10, 20]

# %%
# Delete using index

# %%
nums = [1, 2, 3]

# %%
del nums[1]

# %%
nums
# Out:
# [1, 3]

# %%
# Remove all elements

# %%
nums.clear()

# %%
nums
# Out:
# []

# %%
# Length Of List

# %%
nums = [1, 2, 3, 4]

# %%
# Finding length

# %%
len(nums)
# Out:
# 4

# %%
# Checking Elements

# %%
nums = [1, 2, 3]

# %%
# Check if element exists

# %%
2 in nums
# Out:
# True

# %%
# Check if element does not exist

# %%
5 not in nums
# Out:
# True

# %%
# Looping Through List

# %%
fruits = ["apple", "banana", "mango"]

# %%
# Using for loop

# %%
for fruit in fruits:
    fruit
    print(fruit)
# Out:
# apple
# banana
# mango

# %%
# Using range and index

# %%
for i in range(len(fruits)):
    fruits[i]
    print(fruits[i])
# Out:
# apple
# banana
# mango

# %%
# Sorting Lists

# %%
nums = [4, 1, 3, 2]

# %%
# Sort ascending

# %%
nums.sort()

# %%
nums
# Out:
# [1, 2, 3, 4]

# %%
# Sort descending

# %%
nums.sort(reverse=True)

# %%
nums
# Out:
# [4, 3, 2, 1]

# %%
# Using sorted() function

# %%
nums = [3, 2, 1]

# %%
sorted(nums)
# Out:
# [1, 2, 3]

# %%
# Reversing List

# %%
nums = [1, 2, 3]

# %%
# Reverse the list

# %%
nums.reverse()

# %%
nums
# Out:
# [3, 2, 1]

# %%
# Copying Lists

# %%
a = [1, 2, 3]

# %%
# Copying list

# %%
b = a.copy()

# %%
b
# Out:
# [1, 2, 3]

# %%
# Joining Lists

# %%
a = [1, 2]
b = [3, 4]

# %%
# Joining two lists

# %%
a + b
# Out:
# [1, 2, 3, 4]

# %%
# Repeating Lists

# %%
nums = [1, 2]

# %%
# Repeating list

# %%
nums * 3
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
# Common List Functions

# %%
nums = [4, 2, 8, 1]

# %%
# Maximum value

# %%
max(nums)
# Out:
# 8

# %%
# Minimum value

# %%
min(nums)
# Out:
# 1

# %%
# Sum of elements

# %%
sum(nums)
# Out:
# 15

# %%
# count() Method

# %%
nums = [1, 2, 2, 3]

# %%
# Count occurrences

# %%
nums.count(2)
# Out:
# 2

# %%
# index() Method

# %%
fruits = ["apple", "banana", "mango"]

# %%
# Find index position

# %%
fruits.index("banana")
# Out:
# 1

# %%
# Creating tuple

# %%
t = (1,2,3,4,5)

# %%
empty_tuple =()
print(empty_tuple)
# Out:
# ()

# %%
numbers = (10,20,30,40,50)
print(numbers)
# Out:
# (10, 20, 30, 40, 50)

# %%
number = ("apple","mango")
print(number)
# Out:
# ('apple', 'mango')

# %%
mixed = (1,"Python",7.7,True)
print(mixed)
# Out:
# (1, 'Python', 7.7, True)

# %%
list = ("Apple","banana","mango")

# %%
list[0]
# Out:
# 'Apple'

# %%
list[-1]
# Out:
# 'mango'

# %%
t = (1,2,3,4,5,6,7)

# %%
t[1:4]
# Out:
# (2, 3, 4)

# %%
t[:3]
# Out:
# (1, 2, 3)

# %%
len(t)
# Out:
# 7

# %%
9 in t
# Out:
# False

# %%
for t in t:
    t
    print(t)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
a = [1,2]
b = [3,4]

# %%
a + b
# Out:
# [1, 2, 3, 4]

# %%
a * 2
# Out:
# [1, 2, 1, 2]

# %%
b * 2
# Out:
# [3, 4, 3, 4]

# %%
a = (1,2,3,4,5,6,7,8,9)

# %%
max(a)
# Out:
# 9

# %%
min(a)
# Out:
# 1

# %%
sum(a)
# Out:
# 45

# %%
t = (1, 2, 3, 4)

# %%
print(t)
# Out:
# (1, 2, 3, 4)

# %%
marklist = [1,2,3,4,5]

# %%
tuple(marklist)
# Out:
# (1, 2, 3, 4, 5)

# %%
single = (10,)

# %%
single
# Out:
# (10,)

# %%
type(single)
# Out:
# tuple

# %%
single = (10)

# %%
single
# Out:
# 10

# %%
type(single)
# Out:
# int

# %%
# tuple unpacking

# %%
nums = (1,2,3,4,5,6,7,8)

# %%
a,b,c,d,e,f,g,h = nums

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
d
# Out:
# 4

# %%
e
# Out:
# 5

# %%
f
# Out:
# 6

# %%
g
# Out:
# 7

# %%
h
# Out:
# 8

# %%
nums = (1,"Java",5.5,True)

# %%
a,b,c,d = nums

# %%
a
# Out:
# 1

# %%
b
# Out:
# 'Java'

# %%
c
# Out:
# 5.5

# %%
d
# Out:
# True

# %%
#Create list

# %%
list = ("welcome to python programming")

# %%
list.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
list.lower()
# Out:
# 'welcome to python programming'

# %%
list.title()
# Out:
# 'Welcome To Python Programming'

# %%
list.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(list)
# Out:
# 29

# %%
print("welcome\nto\npython\nprogramming")
# Out:
# welcome
# to
# python
# programming

# %%
# Create set

# %%
s = {1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(s)
# Out:
# set

# %%
empty_set = {}
print(empty_set)
# Out:
# {}

# %%
set = {1,2,3,3,3,4,5}
print(set)
# Out:
# {1, 2, 3, 4, 5}

# %%
set.add(6)
print(set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set.update([7,8])
print(set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
set.remove(5)
print(set)
# Out:
# {1, 2, 3, 4, 6, 7, 8}

# %%
set.pop()
# Out:
# 1

# %%
set.discard(7)
print(set)
# Out:
# {2, 3, 4, 6, 8}

# %%
set.clear()
print(set)
# Out:
# set()

# %%
sets = {10,20,30,40,50}
print(sets)
# Out:
# {50, 20, 40, 10, 30}

# %%
len(sets)
# Out:
# 5

# %%
99 in sets
# Out:
# False

# %%
for sets in sets:
    sets
    print(sets)
# Out:
# 50
# 20
# 40
# 10
# 30

# %%
s = {1,13.5,"String",True}
print(s)
# Out:
# {1, 'String', 13.5}

# %%
set = {3,13.5,"String",True}
print(set)
# Out:
# {True, 'String', 3, 13.5}

# %%
a = {1,2}
b = {3,4}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a = {1,2,3}
b = {2,3,4}

# %%
a - b
# Out:
# {1}

# %%
a.difference(b)
# Out:
# {1}

# %%
a.symmetric_difference(b)
# Out:
# {1, 4}

# %%
nums = {1,2,3,4,5,6}
print(nums)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
max(nums)
# Out:
# 6

# %%
min(nums)
# Out:
# 1

# %%
sum(nums)
# Out:
# 21

# %%
list = (10,20,30,40,50)
print(list)
# Out:
# (10, 20, 30, 40, 50)

# %%
nums = (1,2,3,4,5)
print(nums)
# Out:
# (1, 2, 3, 4, 5)

# %%
# set intersection

# %%
a = {1,2,3}
b = {2,3,4}

# %%
# common elements

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
# using &

# %%
a & b
# Out:
# {2, 3}

# %%
# copying set

# %%
a = {1,2,3}

# %%
# copying sets

# %%
b = a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
# nested sets using frozensets()

# %%
# normal sets cannot contains sets
# use frozenset for nested sets

# %%
a = frozenset({1,2})

# %%
b = {a,3}

# %%
b
# Out:
# {3, frozenset({1, 2})}

# %%
# frozen set

# %%
frozen = frozenset([1,2,3])

# %%
type(frozen)
# Out:
# frozenset

# %%
# create dictionary

# %%
Student = {
    "name":"Shrawan",
    "age":19
}

# %%
print(Student)
# Out:
# {'name': 'Shrawan', 'age': 19}

# %%
Cars = {
    "name":"Sierra",
    "model":"2008"
}
print(Cars)
# Out:
# {'name': 'Sierra', 'model': '2008'}

# %%
flowers = {
    "rose":"red",
    "lotus":"pink",
    "sunflower":"yellow"
}
print(flowers)
# Out:
# {'rose': 'red', 'lotus': 'pink', 'sunflower': 'yellow'}

# %%
states = {
    "Maharashtra":"Mumbai",
    "Gujarat":"Gandhinagar",
    "Karnataka":"Bengaluru"
}
print(states)
# Out:
# {'Maharashtra': 'Mumbai', 'Gujarat': 'Gandhinagar', 'Karnataka': 'Bengaluru'}

# %%
# mixed datatype dictionary

# %%
mixed = {
    1:"one",
    "name":"Python",
    True:100
}
print(mixed)
# Out:
# {1: 100, 'name': 'Python'}

# %%
mixed = {
    3:"Three",
    "name":"Java",
    True:200
}
print(mixed)
# Out:
# {3: 'Three', 'name': 'Java', True: 200}

# %%
mixed["name"]
# Out:
# 'Java'

# %%
mixed.get(3)
# Out:
# 'Three'

# %%
# adding elements

# %%
Student = {
    "name":"Shrawan"
}

# %%
# add new key-value pair

# %%
Student["age"] = 20

# %%
Student
# Out:
# {'name': 'Shrawan', 'age': 20}

# %%
# add another value

# %%
Student["Marks"] = 99

# %%
Student
# Out:
# {'name': 'Shrawan', 'age': 20, 'Marks': 99}

# %%
# modify value

# %%
Student["age"] = 25

# %%
Student
# Out:
# {'name': 'Shrawan', 'age': 25, 'Marks': 99}

# %%
Student.popitem()
# Out:
# ('Marks', 99)

# %%
Student
# Out:
# {'name': 'Shrawan', 'age': 25}

# %%
# delete using del

# %%
del Student["name"]

# %%
Student
# Out:
# {'age': 25}

# %%
# remove all elements

# %%
Student.clear()

# %%
Student
# Out:
# {}

# %%
# Create Dictionary

# %%
Student = {
    "name":"Shrawan",
    "age":19
}

# %%
# finding length

# %%
len(Student)
# Out:
# 2

# %%
# checking keys

# %%
"age" in Student
# Out:
# True

# %%
"salary" in Student
# Out:
# False

# %%
# loop through keys

# %%
Student = {
    "name":"Shrawan",
    "age":19
}

# %%
for Student in Student:
    Student
    print(Student)
# Out:
# name
# age

# %%
# loop through keys

# %%
Student = {
    "name":"Shrawan",
    "age":19
}

# %%
print(Student)
# Out:
# {'name': 'Shrawan', 'age': 19}

# %%
for Student in Student:
    Student
    print(Student)
# Out:
# name
# age

# %%
# Nested Dictionaries

# %%
students = {
    "student1": {
        "name": "Rahul",
        "age": 21
    },
    "student2": {
        "name": "Aman",
        "age": 22
    }
}

# %%
# Access nested value

# %%
students["student1"]["name"]
# Out:
# 'Rahul'

# %%
# get() Method

# %%
student = {
    "name": "Rahul",
    "age": 21
}

# %%
# Get value safely

# %%
student.get("name")
# Out:
# 'Rahul'

# %%
# Default value if key not found

# %%
student.get("course", "Not Found")
# Out:
# 'Not Found'

# %%
# update() Method

# %%
student = {
    "name": "Rahul"
}

# %%
# Update dictionary

# %%
student.update({
    "age": 21,
    "course": "Python"
})

# %%
student
# Out:
# {'name': 'Rahul', 'age': 21, 'course': 'Python'}

# %%
# pop() Method

# %%
student = {
    "name": "Rahul",
    "age": 21
}

# %%
# Remove key and return value

# %%
student.pop("age")
# Out:
# 21

# %%
student
# Out:
# {'name': 'Rahul'}

# %%
# popitem() Method

# %%
student = {
    "name": "Rahul",
    "age": 21
}

# %%
# Remove last inserted item

# %%
student.popitem()
# Out:
# ('age', 21)

# %%
student
# Out:
# {'name': 'Rahul'}

# %%
# Looping Through Dictionary

# %%
student = {
    "name": "Rahul",
    "age": 21
}

# %%
# Loop through keys

# %%
for key in student:
    key
    print(key)
# Out:
# name
# age

# %%
# Loop through values

# %%
for value in student.values():
    value
    print(value)
# Out:
# Rahul
# 21

# %%
# Loop through key-value pairs

# %%
for item in student.items():
    item
    print(item)
# Out:
# ('name', 'Rahul')
# ('age', 21)

# %%
# Dictionary Keys

# %%
student = {
    "name": "Shrawan",
    "age": 21
}

# %%
# Get all keys

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
# Dictionary Values

# %%
student = {
    "name": "Rahul",
    "age": 21
}

# %%
# Get all values

# %%
student.values()
# Out:
# dict_values(['Rahul', 21])

# %%
# Dictionary Items

# %%
student = {
    "name": "Rahul",
    "age": 21
}

# %%
# Get all key-value pairs

# %%
student.items()
# Out:
# dict_items([('name', 'Rahul'), ('age', 21)])

# %%
# Copying Dictionary

# %%
student = {
    "name": "Rahul",
    "age": 21
}

# %%
# Copy dictionary

# %%
new_student = student.copy()

# %%
new_student
# Out:
# {'name': 'Rahul', 'age': 21}
