# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\shrawan\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\shrawan\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shrawan\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrawan\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shrawan\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\shrawan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pandas

# %%
# Install pandas

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
student = {
    "name":"Shrawan",
    "age":19,
    "marks":71
}

# %%
print(student)
# Out:
# {'name': 'Shrawan', 'age': 19, 'marks': 71}

# %%
s = pd.Series(student)

# %%
s
# Out:
# name     Shrawan
# age           19
# marks         71
# dtype: object

# %%
s = pd.Series(5,index = [0,1,2,3,4])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
# Attributes

# %%
s = pd.Series([10,20,30],index = ['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
s*2
# Out:
# a    20
# b    40
# c    60
# dtype: int64

# %%
s = pd.Series([10,None,20])

# %%
s
# Out:
# 0    10.0
# 1     NaN
# 2    20.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    10.0
# 2    20.0
# dtype: float64

# %%
s
# Out:
# 0    10.0
# 1     NaN
# 2    20.0
# dtype: float64

# %%
s.fillna(5)
# Out:
# 0    10.0
# 1     5.0
# 2    20.0
# dtype: float64

# %%
s = pd.Series([1,2,2,3,3,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    3
# 2    2
# 1    1
# Name: count, dtype: int64

# %%
s = pd.Series([10,20,30,40],index = ['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['b']
# Out:
# np.int64(20)

# %%
data = {
    "Roll_No":[100,200,300,400],
    "Name":["Omkar","Shrawan","Sarthak","Tanmay"],
    "Marks":[99,100,101,None]
}

# %%
data
# Out:
# {'Roll_No': [100, 200, 300, 400],
#  'Name': ['Omkar', 'Shrawan', 'Sarthak', 'Tanmay'],
#  'Marks': [99, 100, 101, None]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Roll_No     Name  Marks
# 0      100    Omkar   99.0
# 1      200  Shrawan  100.0
# 2      300  Sarthak  101.0
# 3      400   Tanmay    NaN

# %%
data = {
    "Subjects":['OOP','Java','Python','DSU'],
    "Marks":[90,98,89,88],
    "Grade":[89,90,87,80]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Subjects  Marks  Grade
# 0      OOP     90     89
# 1     Java     98     90
# 2   Python     89     87
# 3      DSU     88     80

# %%
df.to_csv('Marks_data.csv',index = False)

# %%
df = pd.read_csv("Marks_data.csv")

# %%
df
# Out:
#   Subjects  Marks  Grade
# 0      OOP     90     89
# 1     Java     98     90
# 2   Python     89     87
# 3      DSU     88     80

# %%
df.head()
# Out:
#   Subjects  Marks  Grade
# 0      OOP     90     89
# 1     Java     98     90
# 2   Python     89     87
# 3      DSU     88     80

# %%
df.tail()
# Out:
#   Subjects  Marks  Grade
# 0      OOP     90     89
# 1     Java     98     90
# 2   Python     89     87
# 3      DSU     88     80

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Subjects', 'Marks', 'Grade'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Subjects  4 non-null      object
#  1   Marks     4 non-null      int64
#  2   Grade     4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#            Marks     Grade
# count   4.000000   4.00000
# mean   91.250000  86.50000
# std     4.573474   4.50925
# min    88.000000  80.00000
# 25%    88.750000  85.25000
# 50%    89.500000  88.00000
# 75%    92.000000  89.25000
# max    98.000000  90.00000

# %%
df.isnull().sum()
# Out:
# Subjects    0
# Marks       0
# Grade       0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#   Subjects  Marks  Grade
# 0      OOP     90     89
# 1     Java     98     90
# 2   Python     89     87
# 3      DSU     88     80

# %%
df['Marks'] = df['Marks'].astype(int)

# %%
df
# Out:
#   Subjects  Marks  Grade
# 0      OOP     90     89
# 1     Java     98     90
# 2   Python     89     87
# 3      DSU     88     80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Subjects  4 non-null      object
#  1   Marks     4 non-null      int64
#  2   Grade     4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df["Subjects"]
# Out:
# 0       OOP
# 1      Java
# 2    Python
# 3       DSU
# Name: Subjects, dtype: object

# %%
df[["Subjects","Marks"]]
# Out:
#   Subjects  Marks
# 0      OOP     90
# 1     Java     98
# 2   Python     89
# 3      DSU     88

# %%
df=df.sort_values(by="Marks",ascending=False)

# %%
df
# Out:
#   Subjects  Marks  Grade
# 1     Java     98     90
# 0      OOP     90     89
# 2   Python     89     87
# 3      DSU     88     80
