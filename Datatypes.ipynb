# %%
# integer

# %%
# integer means whole number

# %%
age = 20

# %%
print(age,type(age))
# Out:
# 20 <class 'int'>

# %%
marks = 99

# %%
print(marks,type(marks))
# Out:
# 99 <class 'int'>

# %%
temperature = -5

# %%
print(temperature,type(temperature))
# Out:
# -5 <class 'int'>

# %%
# integer operations

# %%
a = 20
b = 10

# %%
# addition

# %%
a + b
# Out:
# 30

# %%
# subtraction

# %%
a - b
# Out:
# 10

# %%
#multiplication

# %%
a * b
# Out:
# 200

# %%
# division

# %%
a / b
# Out:
# 2.0

# %%
# power

# %%
a ** b
# Out:
# 10240000000000

# %%
# floor division

# %%
a // b
# Out:
# 2

# %%
# remainder

# %%
a % b
# Out:
# 0

# %%
# string

# %%
# string means text

# %%
first_name = "Shrawan"
last_name = "gawari"
course = "Python Programming"

# %%
print(type(first_name))
# Out:
# <class 'str'>

# %%
print(type(last_name))
# Out:
# <class 'str'>

# %%
print(type(course))
# Out:
# <class 'str'>

# %%
# string concatenation

# %%
first_name = "Shrawan"
last_name = "Gawari"

# %%
full_name = first_name + "" + last_name

# %%
full_name
# Out:
# 'ShrawanGawari'

# %%
# string repetition

# %%
word = "Python "

# %%
print(word * 3)
# Out:
# Python Python Python

# %%
# string indexing

# %%
language = "Python"

# %%
language [0]
# Out:
# 'P'

# %%
language [1]
# Out:
# 'y'

# %%
language [-1]
# Out:
# 'n'

# %%
language [-2]
# Out:
# 'o'

# %%
# string slicing

# %%
language = "Python Programming"

# %%
language [0:6]
# Out:
# 'Python'

# %%
language [7:18]
# Out:
# 'Programming'

# %%
language [:6]
# Out:
# 'Python'

# %%
language [7:]
# Out:
# 'Programming'

# %%
language [-18:]
# Out:
# 'Python Programming'

# %%
# string methods

# %%
message = "welcome to python programming"

# %%
message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
message.lower()
# Out:
# 'welcome to python programming'

# %%
message.title()
# Out:
# 'Welcome To Python Programming'

# %%
message.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(message)
# Out:
# 29

# %%
#replace

# %%
text = "i like python"

# %%
new_text = text.replace("python","java")

# %%
print(new_text)
# Out:
# i like java

# %%
#split

# %%
text = "omkar rushi shrawan"

# %%
# join

# %%
words = ['python','is','easy']

# %%
sentence = " ".join(words)

# %%
print(sentence)
# Out:
# python is east

# %%
words = ['java','is','easy']

# %%
sentence = " ".join(words)

# %%
print(sentence)
# Out:
# java is easy

# %%
# strip

# %%
text = "   Shrawan   "

# %%
clean_text = text.strip()

# %%
clean_text
# Out:
# 'Shrawan'

# %%
# lstrip remove left spaces

# %%
text = "  Hello"

# %%
text.lstrip()
# Out:
# 'Hello'

# %%
# rstrip remove right spaces

# %%
text = "Hello    "

# %%
text.rstrip()
# Out:
# 'Hello'

# %%
text = "Omkar    "

# %%
text.rstrip()
# Out:
# 'Omkar'

# %%
# String formatting

# %%
name = "Shrawan"
age = "20"

# %%
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Shrawan and I am 20 years old.

# %%
subject = "java"

# %%
print(f"I am good in {subject}.")
# Out:
# I am good in java.

# %%
# mathematical operation inside f-string

# %%
a = 10 
b = 5

# %%
print(f"sum={a+b}")
# Out:
# sum=15

# %%
# format

# %%
name = "Shrawan"
age = 20

# %%
print("My name is {} and I am {} years old.".format(name,age))
# Out:
# My name is Shrawan and I am 20 years old.

# %%
# Boolean

# %%
is_student = True
is_empoyed = False

# %%
print(is_student,type(is_student))
# Out:
# True <class 'bool'>

# %%
print(is_empoyed,type(is_empoyed))
# Out:
# False <class 'bool'>
